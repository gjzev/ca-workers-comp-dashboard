# %%
import pandas as pd
import os

# List of all data files
data_path = '../data/raw/'
files = [
    'FROI-Data-File.xlsx',
    'Table-2_cause.xlsx',
    'Table-2a_cause_detailed.xlsx',
    'Table-3_nature.xlsx',
    'Table-3a_nature_detailed.xlsx',
    'Table-5_age.xlsx',
    'Table-6_gender.xlsx',
    'Table-7_region.xlsx',
    'Table-7a_county.xlsx',
    'Table-16_timeliness.xlsx'
]

# Inspect each file
for file in files:
    print("=" * 70)
    print(f"FILE: {file}")
    print("=" * 70)
    try:
        df = pd.read_excel(os.path.join(data_path, file))
        print(f"Shape: {df.shape[0]:,} rows × {df.shape[1]} columns")
        print(f"Columns: {df.columns.tolist()}")
        print(f"\nFirst 3 rows:")
        print(df.head(3))
        print()
    except Exception as e:
        print(f"ERROR loading file: {e}\n")
# Out:
# ======================================================================
# FILE: FROI-Data-File.xlsx
# ======================================================================
# Shape: 855 rows × 6 columns
# Columns: ['PART_OF_BODY', 'DETAILED_PART_OF_BODY', 'YEAR_OF_INJURY', 'COUNT', 'Unnamed: 4', 'Unnamed: 5']
#
# First 3 rows:
#   PART_OF_BODY DETAILED_PART_OF_BODY  YEAR_OF_INJURY  COUNT  Unnamed: 4  \
# 0         HEAD                 Brain            2010   2767         NaN
# 1         HEAD                 Brain            2011   2724         NaN
# 2         HEAD                 Brain            2012   2593         NaN
#
#   Unnamed: 5
# 0        NaN
# 1        NaN
# 2        NaN
#
# ======================================================================
# FILE: Table-2_cause.xlsx
# ======================================================================
# Shape: 52 rows × 17 columns
# Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16']
#
# First 3 rows:
#                                           Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0  State of California, Department of Industrial ...         NaN         NaN
# 1                  Division of Workers' Compensation         NaN         NaN
# 2    Workers' Compensation Information System (WCIS)         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN        NaN         NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN         NaN
# 2         NaN         NaN         NaN        NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15 Unnamed: 16
# 0          NaN          NaN         NaN
# 1          NaN          NaN         NaN
# 2          NaN          NaN         NaN
#
# ======================================================================
# FILE: Table-2a_cause_detailed.xlsx
# ======================================================================
# Shape: 100 rows × 18 columns
# Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17']
#
# First 3 rows:
#                                           Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0  State of California, Department of Industrial ...        NaN         NaN
# 1                  Division of Workers' Compensation        NaN         NaN
# 2    Workers' Compensation Information System (WCIS)        NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN        NaN         NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN         NaN
# 2         NaN         NaN         NaN        NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16 Unnamed: 17
# 0          NaN          NaN          NaN         NaN
# 1          NaN          NaN          NaN         NaN
# 2          NaN          NaN          NaN         NaN
#
# ======================================================================
# FILE: Table-3_nature.xlsx
# ======================================================================
# Shape: 31 rows × 17 columns
# Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16']
#
# First 3 rows:
#                                           Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0  State of California, Department of Industrial ...         NaN         NaN
# 1                  Division of Workers' Compensation         NaN         NaN
# 2    Workers' Compensation Information System (WCIS)         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN        NaN         NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN         NaN
# 2         NaN         NaN         NaN        NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15 Unnamed: 16
# 0          NaN          NaN         NaN
# 1          NaN          NaN         NaN
# 2          NaN          NaN         NaN
#
# ======================================================================
# FILE: Table-3a_nature_detailed.xlsx
# ======================================================================
# Shape: 72 rows × 18 columns
# Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17']
#
# First 3 rows:
#                                           Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0  State of California, Department of Industrial ...        NaN         NaN
# 1                  Division of Workers' Compensation        NaN         NaN
# 2    Workers' Compensation Information System (WCIS)        NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN        NaN         NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN         NaN
# 2         NaN         NaN         NaN        NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16 Unnamed: 17
# 0          NaN          NaN          NaN         NaN
# 1          NaN          NaN          NaN         NaN
# 2          NaN          NaN          NaN         NaN
#
# ======================================================================
# FILE: Table-5_age.xlsx
# ======================================================================
# Shape: 34 rows × 17 columns
# Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16']
#
# First 3 rows:
#                                           Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0  State of California, Department of Industrial ...         NaN         NaN
# 1                  Division of Workers' Compensation         NaN         NaN
# 2    Workers' Compensation Information System (WCIS)         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN        NaN         NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN         NaN
# 2         NaN         NaN         NaN        NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15 Unnamed: 16
# 0          NaN          NaN         NaN
# 1          NaN          NaN         NaN
# 2          NaN          NaN         NaN
#
# ======================================================================
# FILE: Table-6_gender.xlsx
# ======================================================================
# Shape: 23 rows × 17 columns
# Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16']
#
# First 3 rows:
#                                           Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0  State of California, Department of Industrial ...         NaN         NaN
# 1                  Division of Workers' Compensation         NaN         NaN
# 2    Workers' Compensation Information System (WCIS)         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN        NaN         NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN         NaN
# 2         NaN         NaN         NaN        NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15 Unnamed: 16
# 0          NaN          NaN         NaN
# 1          NaN          NaN         NaN
# 2          NaN          NaN         NaN
#
# ======================================================================
# FILE: Table-7_region.xlsx
# ======================================================================
# Shape: 48 rows × 17 columns
# Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16']
#
# First 3 rows:
#                                           Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0  State of California, Department of Industrial ...         NaN         NaN
# 1                  Division of Workers' Compensation         NaN         NaN
# 2    Workers' Compensation Information System (WCIS)         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN        NaN         NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN         NaN
# 2         NaN         NaN         NaN        NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15 Unnamed: 16
# 0          NaN          NaN         NaN
# 1          NaN          NaN         NaN
# 2          NaN          NaN         NaN
#
# ======================================================================
# FILE: Table-7a_county.xlsx
# ======================================================================
# Shape: 81 rows × 18 columns
# Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17']
#
# First 3 rows:
#                                           Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0  State of California, Department of Industrial ...        NaN         NaN
# 1                  Division of Workers' Compensation        NaN         NaN
# 2    Workers' Compensation Information System (WCIS)        NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN        NaN         NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN         NaN
# 2         NaN         NaN         NaN        NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16 Unnamed: 17
# 0          NaN          NaN          NaN         NaN
# 1          NaN          NaN          NaN         NaN
# 2          NaN          NaN          NaN         NaN
#
# ======================================================================
# FILE: Table-16_timeliness.xlsx
# ======================================================================
# Shape: 34 rows × 10 columns
# Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9']
#
# First 3 rows:
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0  State of California, Department of Industrial ...        NaN        NaN
# 1                  Division of Workers' Compensation        NaN        NaN
# 2    Workers' Compensation Information System (WCIS)        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN        NaN
